# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinth001/Cliff-Walking-RL/blob/main/RANDOM_AGENT_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import tensorflow as tf
import matplotlib.pyplot as plt

env = gym.make("CartPole-v1", render_mode="rgb_array")

state, info = env.reset()
done = False

plt.figure()

while not done:

    frame = env.render()

    plt.imshow(frame)
    plt.axis("off")
    plt.pause(0.03)   # This creates animation
    plt.clf()         # Clear frame for next image

    # Random action using TensorFlow
    action = tf.random.uniform(
        shape=(),
        minval=0,
        maxval=env.action_space.n,
        dtype=tf.int32
    ).numpy()

    state, reward, terminated, truncated, info = env.step(action)

    done = terminated or truncated

env.close()
