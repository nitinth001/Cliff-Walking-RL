# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinth001/Cliff-Walking-RL/blob/main/evaluator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.models import load_model


# Create environment
env = gym.make("CartPole-v1", render_mode="rgb_array")

# Load trained network
q_net = load_model("q_learning_q_net.keras")

def policy(state, explore=0.0):

    action = tf.argmax(q_net(state)[0], output_type=tf.int32)

    if tf.random.uniform(shape=()) <= explore:
        action = tf.random.uniform(shape=(), minval=0, maxval=2, dtype=tf.int32)

    return action


plt.figure()

for episode in range(5):

    state, info = env.reset()
    state = tf.convert_to_tensor([state], dtype=tf.float32)

    done = False

    while not done:

        frame = env.render()

        plt.imshow(frame)
        plt.axis("off")
        plt.pause(0.03)
        plt.clf()

        action = policy(state)

        next_state, reward, terminated, truncated, info = env.step(action.numpy())

        done = terminated or truncated

        state = tf.convert_to_tensor([next_state], dtype=tf.float32)

env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1044/969383009.py in <cell line: 0>()
#      10
#      11 # Load trained network
# ---> 12 q_net = load_model("q_learning_q_net.keras")
#      13
#      14 def policy(state, explore=0.0):
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     198         )
#     199     elif str(filepath).endswith(".keras"):
# --> 200         raise ValueError(
#     201             f"File not found: filepath={filepath}. "
#     202             "Please ensure the file is an accessible `.keras` "
#
# ValueError: File not found: filepath=q_learning_q_net.keras. Please ensure the file is an accessible `.keras` zip file.
